# %% [markdown]
# ## Column Values Normalization

# %%
import pandas as pd;
import numpy as np;
from ydata_profiling import ProfileReport

# %%
cleaned_df = pd.read_csv("../../data/cleaned_responses.csv", low_memory=False)
cleaned_df
# Out:
#      What is your age (# years)? What is your gender?  \
# 0                          40-44                 Male
# 1                          22-24                 Male
# 2                          22-24                 Male
# 3                          22-24               Female
# 4                          55-59                 Male
# ...                          ...                  ...
# 7811                       25-29                 Male
# 7812                       22-24               Female
# 7813                       25-29                 Male
# 7814                       25-29                 Male
# 7815                       50-54                 Male
#
#      In which country do you currently reside?  \
# 0                                    Australia
# 1                                        India
# 2                                        India
# 3                     United States of America
# 4                                  Netherlands
# ...                                        ...
# 7811                                     India
# 7812                                     Other
# 7813                                     China
# 7814                                 Australia
# 7815                                    France
#
#      What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# 0                                       Master’s degree
# 1                                     Bachelor’s degree
# 2                                       Master’s degree
# 3                                     Bachelor’s degree
# 4                                       Master’s degree
# ...                                                 ...
# 7811                                    Master’s degree
# 7812                                  Bachelor’s degree
# 7813                             I prefer not to answer
# 7814                                  Bachelor’s degree
# 7815                                  Bachelor’s degree
#
#      Select the title most similar to your current role (or most recent title if retired)  \
# 0                                                 Other
# 1                                                 Other
# 2                                        Data Scientist
# 3                                        Data Scientist
# 4                                                 Other
# ...                                                 ...
# 7811                                     Data Scientist
# 7812                                              Other
# 7813                                      Data Engineer
# 7814                                              Other
# 7815                                  Software Engineer
#
#      What is the size of the company where you are employed?  \
# 0                                    > 10,000 employees
# 1                                        0-49 employees
# 2                                      50-249 employees
# 3                                    > 10,000 employees
# 4                                        0-49 employees
# ...                                                 ...
# 7811                                     0-49 employees
# 7812                                   50-249 employees
# 7813                                  250-999 employees
# 7814                               1000-9,999 employees
# 7815                                 > 10,000 employees
#
#      Approximately how many individuals are responsible for data science workloads at your place of business?  \
# 0                                                   20+
# 1                                                     0
# 2                                                   20+
# 3                                                   20+
# 4                                                   1-2
# ...                                                 ...
# 7811                                                1-2
# 7812                                                1-2
# 7813                                                5-9
# 7814                                                5-9
# 7815                                                20+
#
#      Does your current employer incorporate machine learning methods into their business?  \
# 0                                         I do not know
# 1                         No (we do not use ML methods)
# 2     We are exploring ML methods (and may one day p...
# 3     We recently started using ML methods (i.e., mo...
# 4     We are exploring ML methods (and may one day p...
# ...                                                 ...
# 7811  We recently started using ML methods (i.e., mo...
# 7812  We are exploring ML methods (and may one day p...
# 7813  We recently started using ML methods (i.e., mo...
# 7814                      No (we do not use ML methods)
# 7815  We have well established ML methods (i.e., mod...
#
#      What is your current yearly compensation (approximate $USD)?  \
# 0                                       250,000-299,999
# 1                                           4,000-4,999
# 2                                         10,000-14,999
# 3                                         80,000-89,999
# 4                                                $0-999
# ...                                                 ...
# 7811                                        1,000-1,999
# 7812                                        5,000-7,499
# 7813                                      20,000-24,999
# 7814                                      60,000-69,999
# 7815                                      60,000-69,999
#
#      Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?  \
# 0                                       $10,000-$99,999
# 1                                              $0 (USD)
# 2                                             $100-$999
# 3                                              $0 (USD)
# 4                                             $100-$999
# ...                                                 ...
# 7811                                          $100-$999
# 7812                                          $100-$999
# 7813                                          $100-$999
# 7814                                    $10,000-$99,999
# 7815                                           $0 (USD)
#
#       ... Have you ever used a TPU (tensor processing unit)?  \
# 0     ...                                           Used TPU
# 1     ...                                              Never
# 2     ...                                           Used TPU
# 3     ...                                           Used TPU
# 4     ...                                              Never
# ...   ...                                                ...
# 7811  ...                                              Never
# 7812  ...                                              Never
# 7813  ...                                           Used TPU
# 7814  ...                                              Never
# 7815  ...                                              Never
#
#      For how many years have you used machine learning methods?  \
# 0                                             2-3 years
# 1                                             < 1 years
# 2                                             2-3 years
# 3                                             3-4 years
# 4                                             < 1 years
# ...                                                 ...
# 7811                                          2-3 years
# 7812                                          1-2 years
# 7813                                          1-2 years
# 7814                                          1-2 years
# 7815                                          4-5 years
#
#      Who/what are your favorite media sources that report on data science topics?  \
# 0     Podcasts (Chai Time Data Science, Linear Digre...
# 1     YouTube (Cloud AI Adventures, Siraj Raval, etc...
# 2     Kaggle (forums, blog, social media, etc), Cour...
# 3     Hacker News (https://news.ycombinator.com/), B...
# 4     Kaggle (forums, blog, social media, etc), Cour...
# ...                                                 ...
# 7811  Hacker News (https://news.ycombinator.com/), K...
# 7812                                              Other
# 7813                                              Other
# 7814  Hacker News (https://news.ycombinator.com/), R...
# 7815  Blogs (Towards Data Science, Medium, Analytics...
#
#      On which platforms have you begun or completed data science courses?  \
# 0     Coursera, edX, DataCamp, University Courses (r...
# 1                                                 Other
# 2     Udacity, Coursera, edX, Kaggle Courses (i.e. K...
# 3     Udemy, University Courses (resulting in a univ...
# 4                                              Coursera
# ...                                                 ...
# 7811  Kaggle Courses (i.e. Kaggle Learn), LinkedIn L...
# 7812  Udacity, Coursera, edX, Kaggle Courses (i.e. K...
# 7813                 Kaggle Courses (i.e. Kaggle Learn)
# 7814                      Coursera, edX, Fast.ai, Udemy
# 7815                               Coursera, edX, Udemy
#
#      Which of the following integrated development environments (IDE's) do you use on a regular basis?  \
# 0     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 1         Jupyter (JupyterLab, Jupyter Notebooks, etc)
# 2     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 3     Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 4         Jupyter (JupyterLab, Jupyter Notebooks, etc)
# ...                                                 ...
# 7811  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 7812  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 7813  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 7814  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 7815  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
#
#      What programming languages do you use on a regular basis?  \
# 0                                  Python, R, SQL, Bash
# 1                                           Python, SQL
# 2                                       Python, R, Bash
# 3                                                Python
# 4                                           Python, SQL
# ...                                                 ...
# 7811                                     Python, MATLAB
# 7812                                             Python
# 7813                                             Python
# 7814                                Python, SQL, MATLAB
# 7815                            Python, SQL, Java, Bash
#
#      What data visualization libraries or tools do you use on a regular basis?  \
# 0            Ggplot / ggplot2 ,  Matplotlib ,  Seaborn
# 1      Matplotlib ,  Plotly / Plotly Express ,  Seab...
# 2      Matplotlib ,  Plotly / Plotly Express ,  Boke...
# 3                Matplotlib ,  Plotly / Plotly Express
# 4                       Matplotlib ,  D3.js ,  Seaborn
# ...                                                 ...
# 7811                                        Matplotlib
# 7812                             Matplotlib ,  Seaborn
# 7813                                           Seaborn
# 7814   Matplotlib ,  Plotly / Plotly Express ,  Boke...
# 7815                                        Matplotlib
#
#      Which types of specialized hardware do you use on a regular basis?  \
# 0                                            CPUs, GPUs
# 1                                            CPUs, GPUs
# 2                                            CPUs, GPUs
# 3                                                  CPUs
# 4                                                  CPUs
# ...                                                 ...
# 7811                                         CPUs, GPUs
# 7812                                         CPUs, GPUs
# 7813                                               GPUs
# 7814                                         CPUs, GPUs
# 7815                                               CPUs
#
#      Which of the following ML algorithms do you use on a regular basis?  \
# 0     Linear or Logistic Regression, Convolutional N...
# 1     Linear or Logistic Regression, Decision Trees ...
# 2     Linear or Logistic Regression, Dense Neural Ne...
# 3     Linear or Logistic Regression, Decision Trees ...
# 4     Linear or Logistic Regression, Bayesian Approa...
# ...                                                 ...
# 7811  Linear or Logistic Regression, Decision Trees ...
# 7812  Linear or Logistic Regression, Decision Trees ...
# 7813  Dense Neural Networks (MLPs, etc), Recurrent N...
# 7814  Linear or Logistic Regression, Decision Trees ...
# 7815  Linear or Logistic Regression, Decision Trees ...
#
#      Which of the following machine learning frameworks do you use on a regular basis?
# 0       Scikit-learn ,   TensorFlow ,  Keras ,  Rand...
# 1       Scikit-learn ,  RandomForest,  Xgboost ,  Li...
# 2       Scikit-learn ,   TensorFlow ,  Keras ,  PyTo...
# 3       Scikit-learn ,   TensorFlow ,  Keras ,  Spar...
# 4                              Scikit-learn ,  PyTorch
# ...                                                 ...
# 7811    Scikit-learn ,   TensorFlow ,  PyTorch ,  Sp...
# 7812            Scikit-learn ,   TensorFlow ,  PyTorch
# 7813              Scikit-learn ,   TensorFlow ,  Keras
# 7814            Scikit-learn ,   TensorFlow ,  PyTorch
# 7815                        Scikit-learn ,  Spark MLib
#
# [7816 rows x 23 columns]

# %% [markdown]
# ### Remove unnecessary details

# %%
# Function to remove text within parentheses and clean up spaces for multiple columns
def clean_columns(df, columns):
    for column in columns:
        if column in df.columns:
            # Remove text within parentheses
            df.loc[:, column] = df[column].str.replace(r"\s*\(.*?\)", "", regex=True)
            # Remove extra spaces around commas and trim leading/trailing spaces
            df.loc[:, column] = df[column].str.replace(r"\s*,\s*", ", ", regex=True).str.strip()
        else:
            print(f"Column '{column}' not found in the DataFrame.")
    return df

# %%
# Specify the columns you want to clean
columns_to_clean = ['On which platforms have you begun or completed data science courses?', 
                    'Which of the following integrated development environments (IDE\'s) do you use on a regular basis?',
                    'What data visualization libraries or tools do you use on a regular basis?',
                    'Which of the following hosted notebook products do you use on a regular basis?',
                    'Which of the following ML algorithms do you use on a regular basis?',
                    'Which categories of ML tools do you use on a regular basis?',
                    'Which of the following machine learning frameworks do you use on a regular basis?',
                    'Who/what are your favorite media sources that report on data science topics?'
                    ]

# Apply the function to the specified columns
cleaned_df = clean_columns(cleaned_df, columns_to_clean)

cleaned_df
# Out:
# Column 'Which of the following hosted notebook products do you use on a regular basis?' not found in the DataFrame.
# Column 'Which categories of ML tools do you use on a regular basis?' not found in the DataFrame.
#      What is your age (# years)? What is your gender?  \
# 0                          40-44                 Male
# 1                          22-24                 Male
# 2                          22-24                 Male
# 3                          22-24               Female
# 4                          55-59                 Male
# ...                          ...                  ...
# 7811                       25-29                 Male
# 7812                       22-24               Female
# 7813                       25-29                 Male
# 7814                       25-29                 Male
# 7815                       50-54                 Male
#
#      In which country do you currently reside?  \
# 0                                    Australia
# 1                                        India
# 2                                        India
# 3                     United States of America
# 4                                  Netherlands
# ...                                        ...
# 7811                                     India
# 7812                                     Other
# 7813                                     China
# 7814                                 Australia
# 7815                                    France
#
#      What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# 0                                       Master’s degree
# 1                                     Bachelor’s degree
# 2                                       Master’s degree
# 3                                     Bachelor’s degree
# 4                                       Master’s degree
# ...                                                 ...
# 7811                                    Master’s degree
# 7812                                  Bachelor’s degree
# 7813                             I prefer not to answer
# 7814                                  Bachelor’s degree
# 7815                                  Bachelor’s degree
#
#      Select the title most similar to your current role (or most recent title if retired)  \
# 0                                                 Other
# 1                                                 Other
# 2                                        Data Scientist
# 3                                        Data Scientist
# 4                                                 Other
# ...                                                 ...
# 7811                                     Data Scientist
# 7812                                              Other
# 7813                                      Data Engineer
# 7814                                              Other
# 7815                                  Software Engineer
#
#      What is the size of the company where you are employed?  \
# 0                                    > 10,000 employees
# 1                                        0-49 employees
# 2                                      50-249 employees
# 3                                    > 10,000 employees
# 4                                        0-49 employees
# ...                                                 ...
# 7811                                     0-49 employees
# 7812                                   50-249 employees
# 7813                                  250-999 employees
# 7814                               1000-9,999 employees
# 7815                                 > 10,000 employees
#
#      Approximately how many individuals are responsible for data science workloads at your place of business?  \
# 0                                                   20+
# 1                                                     0
# 2                                                   20+
# 3                                                   20+
# 4                                                   1-2
# ...                                                 ...
# 7811                                                1-2
# 7812                                                1-2
# 7813                                                5-9
# 7814                                                5-9
# 7815                                                20+
#
#      Does your current employer incorporate machine learning methods into their business?  \
# 0                                         I do not know
# 1                         No (we do not use ML methods)
# 2     We are exploring ML methods (and may one day p...
# 3     We recently started using ML methods (i.e., mo...
# 4     We are exploring ML methods (and may one day p...
# ...                                                 ...
# 7811  We recently started using ML methods (i.e., mo...
# 7812  We are exploring ML methods (and may one day p...
# 7813  We recently started using ML methods (i.e., mo...
# 7814                      No (we do not use ML methods)
# 7815  We have well established ML methods (i.e., mod...
#
#      What is your current yearly compensation (approximate $USD)?  \
# 0                                       250,000-299,999
# 1                                           4,000-4,999
# 2                                         10,000-14,999
# 3                                         80,000-89,999
# 4                                                $0-999
# ...                                                 ...
# 7811                                        1,000-1,999
# 7812                                        5,000-7,499
# 7813                                      20,000-24,999
# 7814                                      60,000-69,999
# 7815                                      60,000-69,999
#
#      Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?  \
# 0                                       $10,000-$99,999
# 1                                              $0 (USD)
# 2                                             $100-$999
# 3                                              $0 (USD)
# 4                                             $100-$999
# ...                                                 ...
# 7811                                          $100-$999
# 7812                                          $100-$999
# 7813                                          $100-$999
# 7814                                    $10,000-$99,999
# 7815                                           $0 (USD)
#
#       ... Have you ever used a TPU (tensor processing unit)?  \
# 0     ...                                           Used TPU
# 1     ...                                              Never
# 2     ...                                           Used TPU
# 3     ...                                           Used TPU
# 4     ...                                              Never
# ...   ...                                                ...
# 7811  ...                                              Never
# 7812  ...                                              Never
# 7813  ...                                           Used TPU
# 7814  ...                                              Never
# 7815  ...                                              Never
#
#      For how many years have you used machine learning methods?  \
# 0                                             2-3 years
# 1                                             < 1 years
# 2                                             2-3 years
# 3                                             3-4 years
# 4                                             < 1 years
# ...                                                 ...
# 7811                                          2-3 years
# 7812                                          1-2 years
# 7813                                          1-2 years
# 7814                                          1-2 years
# 7815                                          4-5 years
#
#      Who/what are your favorite media sources that report on data science topics?  \
# 0     Podcasts, Blogs, Journal Publications, Slack C...
# 1                                 YouTube, Blogs, Other
# 2     Kaggle, Course Forums, YouTube, Podcasts, Jour...
# 3              Hacker News, Blogs, Journal Publications
# 4                          Kaggle, Course Forums, Blogs
# ...                                                 ...
# 7811    Hacker News, Kaggle, YouTube, Slack Communities
# 7812                                              Other
# 7813                                              Other
# 7814       Hacker News, Reddit, Kaggle, Podcasts, Blogs
# 7815                                              Blogs
#
#      On which platforms have you begun or completed data science courses?  \
# 0           Coursera, edX, DataCamp, University Courses
# 1                                                 Other
# 2         Udacity, Coursera, edX, Kaggle Courses, Udemy
# 3                             Udemy, University Courses
# 4                                              Coursera
# ...                                                 ...
# 7811                  Kaggle Courses, LinkedIn Learning
# 7812  Udacity, Coursera, edX, Kaggle Courses, Univer...
# 7813                                     Kaggle Courses
# 7814                      Coursera, edX, Fast.ai, Udemy
# 7815                               Coursera, edX, Udemy
#
#      Which of the following integrated development environments (IDE's) do you use on a regular basis?  \
# 0           Jupyter, Visual Studio / Visual Studio Code
# 1                                               Jupyter
# 2              Jupyter, Spyder, Notepad++, Sublime Text
# 3                                       Jupyter, Spyder
# 4                                               Jupyter
# ...                                                 ...
# 7811                Jupyter, PyCharm, MATLAB, Notepad++
# 7812  Jupyter, Atom, Visual Studio / Visual Studio C...
# 7813                                   Jupyter, PyCharm
# 7814  Jupyter, MATLAB, Visual Studio / Visual Studio...
# 7815        Jupyter, Visual Studio / Visual Studio Code
#
#      What programming languages do you use on a regular basis?  \
# 0                                  Python, R, SQL, Bash
# 1                                           Python, SQL
# 2                                       Python, R, Bash
# 3                                                Python
# 4                                           Python, SQL
# ...                                                 ...
# 7811                                     Python, MATLAB
# 7812                                             Python
# 7813                                             Python
# 7814                                Python, SQL, MATLAB
# 7815                            Python, SQL, Java, Bash
#
#      What data visualization libraries or tools do you use on a regular basis?  \
# 0                 Ggplot / ggplot2, Matplotlib, Seaborn
# 1          Matplotlib, Plotly / Plotly Express, Seaborn
# 2     Matplotlib, Plotly / Plotly Express, Bokeh, Se...
# 3                   Matplotlib, Plotly / Plotly Express
# 4                            Matplotlib, D3.js, Seaborn
# ...                                                 ...
# 7811                                         Matplotlib
# 7812                                Matplotlib, Seaborn
# 7813                                            Seaborn
# 7814  Matplotlib, Plotly / Plotly Express, Bokeh, Se...
# 7815                                         Matplotlib
#
#      Which types of specialized hardware do you use on a regular basis?  \
# 0                                            CPUs, GPUs
# 1                                            CPUs, GPUs
# 2                                            CPUs, GPUs
# 3                                                  CPUs
# 4                                                  CPUs
# ...                                                 ...
# 7811                                         CPUs, GPUs
# 7812                                         CPUs, GPUs
# 7813                                               GPUs
# 7814                                         CPUs, GPUs
# 7815                                               CPUs
#
#      Which of the following ML algorithms do you use on a regular basis?  \
# 0     Linear or Logistic Regression, Convolutional N...
# 1     Linear or Logistic Regression, Decision Trees ...
# 2     Linear or Logistic Regression, Dense Neural Ne...
# 3     Linear or Logistic Regression, Decision Trees ...
# 4     Linear or Logistic Regression, Bayesian Approa...
# ...                                                 ...
# 7811  Linear or Logistic Regression, Decision Trees ...
# 7812  Linear or Logistic Regression, Decision Trees ...
# 7813   Dense Neural Networks, Recurrent Neural Networks
# 7814  Linear or Logistic Regression, Decision Trees ...
# 7815  Linear or Logistic Regression, Decision Trees ...
#
#      Which of the following machine learning frameworks do you use on a regular basis?
# 0         Scikit-learn, TensorFlow, Keras, RandomForest
# 1         Scikit-learn, RandomForest, Xgboost, LightGBM
# 2              Scikit-learn, TensorFlow, Keras, PyTorch
# 3           Scikit-learn, TensorFlow, Keras, Spark MLib
# 4                                 Scikit-learn, PyTorch
# ...                                                 ...
# 7811      Scikit-learn, TensorFlow, PyTorch, Spark MLib
# 7812                  Scikit-learn, TensorFlow, PyTorch
# 7813                    Scikit-learn, TensorFlow, Keras
# 7814                  Scikit-learn, TensorFlow, PyTorch
# 7815                           Scikit-learn, Spark MLib
#
# [7816 rows x 23 columns]

# %% [markdown]
# ### Normalize the features value

# %% [markdown]
# #### Normalizing feature : What is the size of the company where you are employed?

# %%
# Function to normalize company size categories
def normalize_company_size(df, column):
    # Dictionary to map detailed company size ranges to normalized versions
    size_normalization_dict = {
        r"0-49 employees": "Small",
        r"50-249 employees": "Medium",
        r"250-999 employees": "Mid-Large",
        r"1000-9,999 employees": "Large",
        r"> 10,000 employees": "Enterprise"
    }
    
    # Apply replacements using the dictionary
    for pattern, replacement in size_normalization_dict.items():
        df[column] = df[column].str.replace(pattern, replacement, regex=True)
    
    return df

# Apply the normalization function
normalize_company_size(cleaned_df, 'What is the size of the company where you are employed?')

# Display the normalized column
cleaned_df['What is the size of the company where you are employed?'].value_counts()
# Out:
# What is the size of the company where you are employed?
# Small         2232
# Enterprise    1800
# Large         1517
# Medium        1274
# Mid-Large      993
# Name: count, dtype: int64

# %% [markdown]
# Normalizing feature : What is your current yearly compensation (approximate $USD)? <br/> <br/>
#
# - **Removing $ symbol**: This step ensures that any dollar signs in the compensation values are stripped out, allowing for easier numerical processing. <br/>
# - **Mean Value**: For ranges defined with a hyphen (e.g., "50,000 - 70,000"), the average of the lower and upper bounds is calculated to represent a single numerical value. <br/>
# - **Normalize value**: The calculated compensation values are then normalized using min-max normalization, which scales the values to a range of 0 to 1. This is useful for subsequent analysis and modeling. <br/>

# %%
# # Function to extract minimum and maximum values
# # Function to extract minimum and maximum values
# def parse_salary_range(salary_range):
#     try:
#         # Remove unwanted characters like $ and commas
#         clean_range = salary_range.replace("$", "").replace(",", "").strip()
        
#         # Handle cases like "> 500000" and "< 1000"
#         if clean_range.startswith(">"):
#             min_salary = int(clean_range[1:].strip())
#             max_salary = 0  # Undefined upper limit
#         elif clean_range.startswith("<"):
#             min_salary = 0  # Undefined lower limit
#             max_salary = int(clean_range[1:].strip())
#         else:
#             # Split the range into parts using '-' as a separator
#             parts = clean_range.split('-')
            
#             # If only one value is present, use it for both min and max
#             if len(parts) == 1:
#                 min_salary = max_salary = int(parts[0])
#             else:
#                 min_salary, max_salary = map(int, parts)  # Convert both parts to integers
#         return min_salary, max_salary
#     except (ValueError, AttributeError):
#         # Handle invalid or unexpected formats gracefully
#         return None, None

# # Apply the function to the DataFrame
# cleaned_df[['Min_Salary', 'Max_Salary']] = cleaned_df['What is your current yearly compensation (approximate $USD)?'].apply(
#     lambda x: pd.Series(parse_salary_range(x))
# )

# cleaned_df

# %%
# Define a function to clean and extract the main tool category
def extract_main_tool(text):
    # Step 1: Split by comma, then take the first part
    main_tool = text.split(',')[0].strip()
    
    # Step 2: Check for "Other" and ignore it if found
    if main_tool.lower() == "other":
        return "Other"
    
    # Step 3: Split by the first '(' to remove details in parentheses, if any
    return main_tool.split('(')[0].strip()

# Apply the function to the column
cleaned_df['What is the primary tool that you use at work or school to analyze data?'] = cleaned_df[
    'What is the primary tool that you use at work or school to analyze data?'].apply(extract_main_tool)

# Convert the column to categorical type
cleaned_df['What is the primary tool that you use at work or school to analyze data?'] = cleaned_df[
    'What is the primary tool that you use at work or school to analyze data?'].astype('category')

# Verify the unique values after normalization
print(cleaned_df['What is the primary tool that you use at work or school to analyze data?'].unique())
# Out:
# ['Local development environments', 'Basic statistical software', 'Other', 'Advanced statistical software', 'Cloud-based data software & APIs', 'Business intelligence software']
# Categories (6, object): ['Advanced statistical software', 'Basic statistical software', 'Business intelligence software', 'Cloud-based data software & APIs', 'Local development environments', 'Other']

# %%
# Create the final profile report
profile_preprocessed_survey_check = ProfileReport(cleaned_df)
profile_preprocessed_survey_check.to_file('normalized_survey_profile.html')
# Out:
# Summarize dataset: 100%|██████████| 32/32 [00:07<00:00,  4.24it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:15<00:00, 15.41s/it]
# Render HTML: 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 66.66it/s]

# %%
# Save to a new CSV
cleaned_df.to_csv("../../data/normalized_normalized_survey.csv", index=False)
