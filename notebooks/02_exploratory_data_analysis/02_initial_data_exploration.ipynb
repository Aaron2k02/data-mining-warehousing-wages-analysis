# %% [markdown]
# # dtale Setup

# %%
pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\python313\lib\site-packages (3.15.1)
# Requirement already satisfied: dash-colorscales in c:\python313\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in c:\python313\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: future>=0.14.0 in c:\python313\lib\site-packages (from dtale) (1.0.0)
# Requirement already satisfied: missingno in c:\python313\lib\site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in c:\python313\lib\site-packages (from dtale) (2.2.3)
# Requirement already satisfied: squarify in c:\python313\lib\site-packages (from dtale) (0.4.4)
# Requirement already satisfied: strsimpy in c:\python313\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in c:\users\muqri qawiem\appdata\roaming\python\python313\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in c:\python313\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in c:\python313\lib\site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in c:\python313\lib\site-packages (from dtale) (2024.8.30)
# Requirement already satisfied: dash-bootstrap-components in c:\python313\lib\site-packages (from dtale) (1.6.0)
# Requirement already satisfied: lz4 in c:\python313\lib\site-packages (from dtale) (4.3.3)
# Requirement already satisfied: cycler in c:\python313\lib\site-packages (from dtale) (0.12.1)
# Requirement already satisfied: dash in c:\python313\lib\site-packages (from dtale) (2.18.2)
# Requirement already satisfied: seaborn in c:\python313\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: werkzeug in c:\python313\lib\site-packages (from dtale) (3.0.6)
# Requirement already satisfied: Flask-Compress in c:\python313\lib\site-packages (from dtale) (1.17)
# Requirement already satisfied: scikit-learn in c:\python313\lib\site-packages (from dtale) (1.5.2)
# Requirement already satisfied: statsmodels in c:\python313\lib\site-packages (from dtale) (0.14.4)
# Requirement already satisfied: networkx in c:\python313\lib\site-packages (from dtale) (3.4.2)
# Requirement already satisfied: numpy in c:\python313\lib\site-packages (from dtale) (2.1.3)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\python313\lib\site-packages (from dtale) (3.1.5)
# Requirement already satisfied: xarray in c:\python313\lib\site-packages (from dtale) (2024.10.0)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in c:\python313\lib\site-packages (from dtale) (1.14.1)
# Requirement already satisfied: et-xmlfile in c:\python313\lib\site-packages (from dtale) (2.0.0)
# Requirement already satisfied: plotly in c:\python313\lib\site-packages (from dtale) (5.24.1)
# Requirement already satisfied: Flask in c:\python313\lib\site-packages (from dtale) (3.0.3)
# Requirement already satisfied: itsdangerous in c:\python313\lib\site-packages (from dtale) (2.2.0)
# Requirement already satisfied: requests in c:\python313\lib\site-packages (from dtale) (2.32.3)
# Requirement already satisfied: kaleido in c:\python313\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: matplotlib in c:\python313\lib\site-packages (from dtale) (3.9.2)
# Requirement already satisfied: soupsieve>1.2 in c:\python313\lib\site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.6)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\python313\lib\site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\python313\lib\site-packages (from dash->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\python313\lib\site-packages (from dash->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\python313\lib\site-packages (from dash->dtale) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\python313\lib\site-packages (from dash->dtale) (4.12.2)
# Requirement already satisfied: retrying in c:\python313\lib\site-packages (from dash->dtale) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\muqri qawiem\appdata\roaming\python\python313\site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in c:\python313\lib\site-packages (from dash->dtale) (75.3.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\python313\lib\site-packages (from Flask->dtale) (3.1.4)
# Requirement already satisfied: click>=8.1.3 in c:\python313\lib\site-packages (from Flask->dtale) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\python313\lib\site-packages (from Flask->dtale) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python313\lib\site-packages (from plotly->dtale) (9.0.0)
# Requirement already satisfied: packaging in c:\users\muqri qawiem\appdata\roaming\python\python313\site-packages (from plotly->dtale) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\python313\lib\site-packages (from werkzeug->dtale) (3.0.2)
# Requirement already satisfied: brotli in c:\python313\lib\site-packages (from Flask-Compress->dtale) (1.1.0)
# Requirement already satisfied: zstandard in c:\python313\lib\site-packages (from Flask-Compress->dtale) (0.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python313\lib\site-packages (from matplotlib->dtale) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python313\lib\site-packages (from matplotlib->dtale) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python313\lib\site-packages (from matplotlib->dtale) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\python313\lib\site-packages (from matplotlib->dtale) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python313\lib\site-packages (from matplotlib->dtale) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\muqri qawiem\appdata\roaming\python\python313\site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python313\lib\site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python313\lib\site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python313\lib\site-packages (from requests->dtale) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python313\lib\site-packages (from requests->dtale) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python313\lib\site-packages (from requests->dtale) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\python313\lib\site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\python313\lib\site-packages (from scikit-learn->dtale) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\python313\lib\site-packages (from statsmodels->dtale) (0.5.6)
# Requirement already satisfied: colorama in c:\users\muqri qawiem\appdata\roaming\python\python313\site-packages (from click>=8.1.3->Flask->dtale) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\python313\lib\site-packages (from importlib-metadata->dash->dtale) (3.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\python313\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\python313\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\muqri qawiem\appdata\roaming\python\python313\site-packages (from plotly) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dtale
import pandas as pd

df = pd.read_csv('../../data/interm/cleaned_responses.csv')

# launch dtale in browser
d = dtale.show(df, port=4000)
print(d._main_url)
# Out:
# http://S340-PAD:4000/dtale/main/1

# %%
# end dtale session
d.kill()
# Out:
# 2024-11-11 13:43:58,185 - INFO     - Executing shutdown...
# 2024-11-11 13:43:58,189 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %% [markdown]
# # Simple EDA Questions

# %% [markdown]
# ## General Data Exploration

# %% [markdown]
# #### 1. What is the distribution of age among respondents?

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

# Enable offline mode for Plotly in Jupyter
init_notebook_mode(connected=True)

# Your dataset
df = pd.read_csv('../../data/interm/cleaned_responses.csv')

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
    df = df.to_frame(index=False)

# Remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What is your age (# years)?'])]['What is your age (# years)?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What is your age (# years)? Value Counts'},
    'xaxis': {'title': {'text': 'What is your age (# years)?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

# Display the chart
iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\3361182843.py:20: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="33f523c3-77e2-473f-911d-4eaaee18efb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33f523c3-77e2-473f-911d-4eaaee18efb5")) {                    Plotly.newPlot(                        "33f523c3-77e2-473f-911d-4eaaee18efb5",                        [{"name":"Frequency","x":["25-29","30-34","35-39","22-24","40-44","45-49","50-54","18-21","55-59","60-69","70+"],"y":[2562,2091,1439,1319,985,650,474,320,268,213,52],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"mar ...
#
# var gd = document.getElementById(

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. What is the gender distribution?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
from plotly.offline import iplot, init_notebook_mode

init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What is your gender?'])]['What is your gender?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What is your gender? Value Counts'},
    'xaxis': {'title': {'text': 'What is your gender?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\1805382376.py:22: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="c470fa2c-c300-4cbb-968f-c0a1d99d895c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c470fa2c-c300-4cbb-968f-c0a1d99d895c")) {                    Plotly.newPlot(                        "c470fa2c-c300-4cbb-968f-c0a1d99d895c",                        [{"name":"Frequency","x":["Male","Female"],"y":[8928,1445],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{" ...
#
# var gd = document.getElementById('c470fa2c-c300-4cbb-968f-c0a1d99d895c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var displ
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. What is the distribution of respondents across different countries?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'


if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['In which country do you currently reside?'])]['In which country do you currently reside?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'In which country do you currently reside? Value Counts'},
    'xaxis': {'title': {'text': 'In which country do you currently reside?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\1918722260.py:24: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="b00b5337-5e9a-4c0a-a255-36cf5599d0d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b00b5337-5e9a-4c0a-a255-36cf5599d0d5")) {                    Plotly.newPlot(                        "b00b5337-5e9a-4c0a-a255-36cf5599d0d5",                        [{"name":"Frequency","x":["India","United States of America","Other","Brazil","Japan","Russia","Germany","United Kingdom of Great Britain and Northern Ireland","Spain","Canada","France","China","Australia","Italy","Nigeria","Poland","Turkey","Taiwan","Colombia","Mexico","Ukraine","Netherlands","Pakistan","South Korea","Indonesia","Singapore","Argentina","Portugal","Israel","South Africa","Switzerland","Chile","Viet Nam","Sweden","Kenya","Greece","Belgium","Morocco","Peru","Egypt","Iran, Islamic Republic of...","Hong Kong (S.A.R.)","Bangladesh","Malaysia","Romania","Belarus","Ireland","Austria","Norway","Republic of Korea","Thailand","Czech Republic","Hungary","Denmark","New Zealand","Saudi Arabia","Philippines","Algeria","Tunisia"],"y":[1896,1870,547,459,405,366,320,292,276,257,240,199,172,167,160,139,138,134,117,115,113,102,98,93,89,88,84,77,70,70,66,61,60,57,56,51,47,47,47,46,44,43,42,40,40,39,38,36,36,36,36,35,35,34,34,34,32,25,23],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#720 ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ## Education and Professional Background

# %% [markdown]
# #### 4. What are the highest levels of formal education attained by respondents?

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

# Enable Plotly in offline mode
init_notebook_mode(connected=True)



# If the DataFrame has DateTimeIndex or MultiIndex, convert it
if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
    df = df.to_frame(index=False)

# Remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # Ensure column names are strings

# Filter and prepare the data for plotting
s = df[~pd.isnull(df['What is the highest level of formal education that you have attained or plan to attain within the next 2 years?'])]['What is the highest level of formal education that you have attained or plan to attain within the next 2 years?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]

# Create the bar chart
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What is the highest level of formal education that you have attained or plan to attain within the next 2 years? Value Counts'},
    'xaxis': {'title': {'text': 'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\10748426.py:21: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="51e4ba2d-6440-4081-b754-2a62d159a12e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51e4ba2d-6440-4081-b754-2a62d159a12e")) {                    Plotly.newPlot(                        "51e4ba2d-6440-4081-b754-2a62d159a12e",                        [{"name":"Frequency","x":["Master\u2019s degree","Bachelor\u2019s degree","Doctoral degree","Professional degree","Some college\u002funiversity study without earning a bachelor\u2019s degree","I prefer not to answer","No formal education past high school"],"y":[4942,2710,1830,356,317,125,93],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":" ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 5. What are the most common job titles among respondents?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'


if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['Select the title most similar to your current role (or most recent title if retired)'])]['Select the title most similar to your current role (or most recent title if retired)']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'Select the title most similar to your current role (or most recent title if retired) Value Counts'},
    'xaxis': {'title': {'text': 'Select the title most similar to your current role (or most recent title if retired)'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))

iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\3616300691.py:24: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="0e330e6c-647e-4cac-9d29-b0591bef1deb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e330e6c-647e-4cac-9d29-b0591bef1deb")) {                    Plotly.newPlot(                        "0e330e6c-647e-4cac-9d29-b0591bef1deb",                        [{"name":"Frequency","x":["Data Scientist","Software Engineer","Data Analyst","Other","Research Scientist","Product\u002fProject Manager","Business Analyst","Data Engineer","Statistician","DBA\u002fDatabase Engineer"],"y":[3275,1880,1164,1142,1089,538,513,457,205,110],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercar ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 6. What is the distribution of company sizes where respondents are employed?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What is the size of the company where you are employed?'])]['What is the size of the company where you are employed?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What is the size of the company where you are employed? Value Counts'},
    'xaxis': {'title': {'text': 'What is the size of the company where you are employed?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2023325453.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="9f7148a5-ddb0-4797-84d0-686e168c3354" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f7148a5-ddb0-4797-84d0-686e168c3354")) {                    Plotly.newPlot(                        "9f7148a5-ddb0-4797-84d0-686e168c3354",                        [{"name":"Frequency","x":["Small","Enterprise","Large","Medium","Mid-Large"],"y":[2890,2361,2042,1712,1368],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...
#
# var gd = document.getElementById('9
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 7. How many individuals are responsible for data science workloads in different companies?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['Approximately how many individuals are responsible for data science workloads at your place of business?'])]['Approximately how many individuals are responsible for data science workloads at your place of business?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': ('Approximately how many individuals are responsible for data science workloads at your place of business?? Value Counts')},
    'xaxis': {'title': {'text': ('Approximately how many individuals are responsible for data science workloads at your place of business??')}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2389785743.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="165d80e2-0b65-4787-b592-6972e291513a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("165d80e2-0b65-4787-b592-6972e291513a")) {                    Plotly.newPlot(                        "165d80e2-0b65-4787-b592-6972e291513a",                        [{"name":"Frequency","x":["Small team","Very large team","Medium team","No dedicated team","Large team"],"y":[4152,2454,1438,1255,1074],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidt ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Machine Learning Integration & Usage

# %% [markdown]
# #### 8. What percentage of respondents' employers incorporate machine learning methods?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['Does your current employer incorporate machine learning methods into their business?'])]['Does your current employer incorporate machine learning methods into their business?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'Does your current employer incorporate machine learning methods into their business? Value Counts'},
    'xaxis': {'title': {'text': 'Does your current employer incorporate machine learning methods into their business?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\1620296806.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="eab40fff-518f-4c12-a849-9c3d1c76a21e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eab40fff-518f-4c12-a849-9c3d1c76a21e")) {                    Plotly.newPlot(                        "eab40fff-518f-4c12-a849-9c3d1c76a21e",                        [{"name":"Frequency","x":["Recently Started","Exploring","Well Established","No ML Usage","Insights Only","Unknown"],"y":[2271,2229,2102,1762,1258,751],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorba ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 9. What is the distribution of the number of years respondents have used machine learning methods?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['For how many years have you used machine learning methods?'])]['For how many years have you used machine learning methods?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'For how many years have you used machine learning methods? Value Counts'},
    'xaxis': {'title': {'text': 'For how many years have you used machine learning methods?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2319890914.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="08295ce1-9c73-42af-86a7-4fb682e07c3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08295ce1-9c73-42af-86a7-4fb682e07c3e")) {                    Plotly.newPlot(                        "08295ce1-9c73-42af-86a7-4fb682e07c3e",                        [{"name":"Frequency","x":["No experience","Entry level","Junior","Mid-level","Senior","Expert"],"y":[2996,2681,2513,1683,326,174],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0," ...
#
# var gd
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 10. What programming languages are recommended by respondents for aspiring data scientists to learn first?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What programming language would you recommend an aspiring data scientist to learn first?'])]['What programming language would you recommend an aspiring data scientist to learn first?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': ('What programming language would you recommend an aspiring data scientist to learn first?? Value Counts')},
    'xaxis': {'title': {'text': ('What programming language would you recommend an aspiring data scientist to learn first??')}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2816431586.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="a664f882-a908-4f2c-87b0-64e21e9e9679" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a664f882-a908-4f2c-87b0-64e21e9e9679")) {                    Plotly.newPlot(                        "a664f882-a908-4f2c-87b0-64e21e9e9679",                        [{"name":"Frequency","x":["Python","R","SQL","Other"],"y":[7980,1056,717,620],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"mar ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Compensation & Spending

# %% [markdown]
# #### 11. What is the distribution of current yearly compensation for respondents?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What is your current yearly compensation (approximate $USD)?'])]['What is your current yearly compensation (approximate $USD)?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What is your current yearly compensation (approximate $USD)? Value Counts'},
    'xaxis': {'title': {'text': 'What is your current yearly compensation (approximate $USD)?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2335476471.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="18c2cc6f-703c-4a66-95dc-dca935af231d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18c2cc6f-703c-4a66-95dc-dca935af231d")) {                    Plotly.newPlot(                        "18c2cc6f-703c-4a66-95dc-dca935af231d",                        [{"name":"Frequency","x":["0-999","10,000-14,999","100,000-124,999","30,000-39,999","40,000-49,999","50,000-59,999","60,000-69,999","70,000-79,999","15,000-19,999","20,000-24,999","125,000-149,999","5,000-7,499","1,000-1,999","25,000-29,999","150,000-199,999","80,000-89,999","90,000-99,999","7,500-9,999","2,000-2,999","3,000-3,999","4,000-4,999","200,000-249,999","300,000-500,000","250,000-299,999","\u003e 500,000"],"y":[1082,694,660,637,632,611,506,468,457,441,439,432,427,421,389,356,323,319,299,238,236,143,60,53,50],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# #### 12. How much have respondents spent on machine learning and/or cloud computing products in the past 5 years?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?'])]['Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': ('Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?? Value Counts')},
    'xaxis': {'title': {'text': ('Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years??')}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2711266161.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="aaaaeba9-c645-4eff-b738-b2462ff05bdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaaaeba9-c645-4eff-b738-b2462ff05bdd")) {                    Plotly.newPlot(                        "aaaaeba9-c645-4eff-b738-b2462ff05bdd",                        [{"name":"Frequency","x":["No spending","Moderate spending","High spending","Low spending","Very high spending","Ultra high spending"],"y":[3214,2019,1876,1231,1143,890],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{ ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 13. What is the relationship between yearly compensation and money spent on machine learning/cloud computing?

# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import re

# Enable Plotly in offline mode
init_notebook_mode(connected=True)

# Load your dataset
df = pd.read_csv('../../data/interm/cleaned_responses.csv')

# Ensure the column names are correctly referenced
compensation_column = 'What is your current yearly compensation (approximate $USD)?'
spending_column = 'Approximately how much money have you spent on machine learning and/or cloud computing products at your work in the past 5 years?'

# Function to convert range strings to average values
def convert_to_avg(value):
    if isinstance(value, str):
        match = re.match(r'(\d+),(\d+)-(\d+),(\d+)', value)
        if match:
            low = int(match.group(1) + match.group(2))
            high = int(match.group(3) + match.group(4))
            return (low + high) / 2
    return value

# Apply the conversion function
df[compensation_column] = df[compensation_column].apply(convert_to_avg).astype(float, errors='ignore')
df[spending_column] = df[spending_column].apply(convert_to_avg).astype(float, errors='ignore')

# Filter and prepare the data for plotting
df = df.dropna(subset=[compensation_column, spending_column])
df[compensation_column] = pd.to_numeric(df[compensation_column], errors='coerce')
df[spending_column] = pd.to_numeric(df[spending_column], errors='coerce')

# Create the scatter plot
scatter = go.Scatter(
    x=df[compensation_column],
    y=df[spending_column],
    mode='markers',
    marker=dict(size=10, color='blue', opacity=0.6),
    text=df['What is your gender?'],  # Optional: add gender or other column for hover text
    name='Compensation vs. Spending'
)

# Create the figure
figure = go.Figure(data=[scatter], layout=go.Layout({
    'title': {'text': 'Relationship between Yearly Compensation and Money Spent on ML/Cloud Computing'},
    'xaxis': {'title': {'text': 'Yearly Compensation (USD)'}},
    'yaxis': {'title': {'text': 'Money Spent on ML/Cloud Computing (USD)'}},
}))

# Display the chart in the Jupyter notebook
iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="ed0d7d8d-ac97-40eb-8a63-de770397c1e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed0d7d8d-ac97-40eb-8a63-de770397c1e9")) {                    Plotly.newPlot(                        "ed0d7d8d-ac97-40eb-8a63-de770397c1e9",                        [{"marker":{"color":"blue","opacity":0.6,"size":10},"mode":"markers","name":"Compensation vs. Spending","text":["Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Female","Male","Male","Female","Female","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Female","Male","Male","Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Female","Male","Female","Male","Male","Male","Male","Male","Male","Female","Female","Female","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Female","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Male","Female","Female","Male","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Female","Female","Male","Male","Female","Female","Male","Female","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Female","Female","Male","M ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ## Tools & Technologies

# %% [markdown]
# #### 14. What are the primary tools used for data analysis at work or school?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What is the primary tool that you use at work or school to analyze data?'])]['What is the primary tool that you use at work or school to analyze data?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What is the primary tool that you use at work or school to analyze data? Value Counts'},
    'xaxis': {'title': {'text': 'What is the primary tool that you use at work or school to analyze data?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\1325871773.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="4a7cb317-abab-43eb-adff-8fe2313f03c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a7cb317-abab-43eb-adff-8fe2313f03c5")) {                    Plotly.newPlot(                        "4a7cb317-abab-43eb-adff-8fe2313f03c5",                        [{"name":"Frequency","x":["Local development environments","Basic statistical software","Cloud-based data software & APIs","Other","Business intelligence software","Advanced statistical software"],"y":[5657,1673,963,746,690,644],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewid ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 15. How long have respondents been writing code to analyze data?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['How long have you been writing code to analyze data (at work or at school)?'])]['How long have you been writing code to analyze data (at work or at school)?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'How long have you been writing code to analyze data (at work or at school)? Value Counts'},
    'xaxis': {'title': {'text': 'How long have you been writing code to analyze data (at work or at school)?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\1446886734.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="d9ba3839-f8be-4a6c-9b08-d1e662cb8510" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9ba3839-f8be-4a6c-9b08-d1e662cb8510")) {                    Plotly.newPlot(                        "d9ba3839-f8be-4a6c-9b08-d1e662cb8510",                        [{"name":"Frequency","x":["Intermediate","Novice","Beginner","Experienced","Expert"],"y":[2710,2576,1912,1683,1492],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"t ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 16. What data visualization libraries or tools are most commonly used?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['What data visualization libraries or tools do you use on a regular basis?'])]['What data visualization libraries or tools do you use on a regular basis?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'What data visualization libraries or tools do you use on a regular basis? Value Counts'},
    'xaxis': {'title': {'text': 'What data visualization libraries or tools do you use on a regular basis?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\910407710.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="2c7a6564-55f5-4dba-9f43-1dbca63cdcb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c7a6564-55f5-4dba-9f43-1dbca63cdcb8")) {                    Plotly.newPlot(                        "2c7a6564-55f5-4dba-9f43-1dbca63cdcb8",                        [{"name":"Frequency","x":["Matplotlib, Seaborn","Matplotlib","Matplotlib, Plotly \u002f Plotly Express, Seaborn","Ggplot \u002f ggplot2","Ggplot \u002f ggplot2, Matplotlib, Seaborn","Ggplot \u002f ggplot2, Matplotlib","Matplotlib, Plotly \u002f Plotly Express","Ggplot \u002f ggplot2, Matplotlib, Plotly \u002f Plotly Express, Seaborn","Matplotlib, Bokeh, Seaborn","Other","Ggplot \u002f ggplot2, Shiny","Seaborn","D3.js","Matplotlib, Plotly \u002f Plotly Express, Bokeh, Seaborn","Plotly \u002f Plotly Express","Ggplot \u002f ggplot2, Shiny, Plotly \u002f Plotly Express","Matplotlib, D3.js","Ggplot \u002f ggplot2, Plotly \u002f Plotly Express","Ggplot \u002f ggplot2, Matplotlib, Plotly \u002f Plotly Express","Matplotlib, D3.js, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny, Plotly \u002f Plotly Express, Seaborn","Ggplot \u002f ggplot2, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny","Matplotlib, Bokeh","Matplotlib, Other","Matplotlib, Seaborn, Geoplotlib","Ggplot \u002f ggplot2, Matplotlib, Bokeh, Seaborn","Plotly \u002f Plotly Express, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny, Plotly \u002f Plotly Express","Matplotlib, D3.js, Plotly \u002f Plotly Express, Seaborn","Matplotlib, Geoplotlib","Ggplot \u002f ggplot2, Matplotlib, Plotly \u002f Plotly Express, Bokeh, Seaborn","Shiny","Ggplot \u002f ggplot2, D3.js","Matplotlib, Plotly \u002f Plotly Express, Seaborn, Geoplotlib","Ggplot \u002f ggplot2, Matplotlib, Shiny, Plotly \u002f Plotly Express, Bokeh, Seaborn","Ggplot \u002f ggplot2, Plotly \u002f Plotly Express, Seaborn","Ggplot \u002f ggplot2, Matplotlib, D3.js","Matplotlib, D3.js, Plotly \u002f Plotly Express","Ggplot \u002f ggplot2, Shiny, Leaflet \u002f Folium","Matplotlib, Seaborn, Other","Ggplot \u002f ggplot2, Matplotlib, D3.js, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Geoplotlib","Ggplot \u002f ggplot2, Shiny, Plotly \u002f Plotly Express, Leaflet \u002f Folium","Ggplot \u002f ggplot2, Matplotlib, Plotly \u002f Plotly Express, Seaborn, Geoplotlib","Matplotlib, Seaborn, Leaflet \u002f Folium","Ggplot \u002f ggplot2, Matplotlib, Seaborn, Geoplotlib","Matplotlib, D3.js, Bokeh, Seaborn","Matplotlib, Shiny, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny, D3.js, Plotly \u002f Plotly Express, Seaborn","Ggplot \u002f ggplot2, Matplotlib, D3.js, Plotly \u002f Plotly Express, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny, Plotly \u002f Plotly Express, Seaborn, Leaflet \u002f Folium","Ggplot \u002f ggplot2, Other","Ggplot \u002f ggplot2, Shiny, D3.js","Matplotlib, Leaflet \u002f Folium","Matplotlib, Plotly \u002f Plotly Express, Seaborn, Leaflet \u002f Folium","Ggplot \u002f ggplot2, Matplotlib, Plotly \u002f Plotly Express, Geoplotlib","Matplotlib, Plotly \u002f Plotly Express, Bokeh, Seaborn, Leaflet \u002f Folium","D3.js, Seaborn","Ggplot \u002f ggplot2, Matplotlib, Shiny, D3.js, Plotly \u002f Plotly Express","Matplotlib, Shiny","D3.js, Plotly \u002f Plotly Express","Matplotlib, Plotly \u002f Plotly Express, Bokeh","Altair","Geoplotlib","Ggplot \u002f ggplot2, D3.js, Plotly \u002f Plotly Express","Ggplot \u002f ggplot2, Matplotlib, D3.js, Plotly \u002f Plotly Express","Matplotlib, Altair, Seaborn","Shiny, Plotly \u002f Plotly Express","Bokeh","Ggplot \u002f ggplot2, Matplotlib, Altair, Shiny, D3.js, Plotly \u002f Plotly Express, Bokeh, Seaborn, Geoplotlib, Leaflet \u002f Folium","Ggplot \u002f ggplot2, Matplotlib, Shiny, Plotly \u ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# 2024-11-11 13:06:51,113 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1377, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 1343, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 1047, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#                     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 355, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 382, in concat
#     op = _Concatenator(
#         objs,
#     ...<8 lines>...
#         sort=sort,
#     )
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 445, in __init__
#     objs, keys = self._clean_keys_and_objs(objs, keys)
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 507, in _clean_keys_and_objs
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2024-11-11 13:08:53,960 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1377, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 1343, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 1047, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#                     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 355, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 382, in concat
#     op = _Concatenator(
#         objs,
#     ...<8 lines>...
#         sort=sort,
#     )
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 445, in __init__
#     objs, keys = self._clean_keys_and_objs(objs, keys)
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 507, in _clean_keys_and_objs
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# c:\Python313\Lib\site-packages\dtale\dash_application\charts.py:4162: GuessedAtParserWarning:
#
# No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 4162 of the file c:\Python313\Lib\site-packages\dtale\dash_application\charts.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 17. Which machine learning algorithms and frameworks are used regularly?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['Which of the following ML algorithms do you use on a regular basis?'])]['Which of the following ML algorithms do you use on a regular basis?']
chart = pd.value_counts(s).to_frame(name='data')
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'Which of the following ML algorithms do you use on a regular basis? Value Counts'},
    'xaxis': {'title': {'text': 'Which of the following ML algorithms do you use on a regular basis?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\1610116605.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="41cc299b-9ce8-4acd-9971-99f51a10e33e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41cc299b-9ce8-4acd-9971-99f51a10e33e")) {                    Plotly.newPlot(                        "41cc299b-9ce8-4acd-9971-99f51a10e33e",                        [{"name":"Frequency","x":["Linear or Logistic Regression, Decision Trees or Random Forests","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines","Linear or Logistic Regression","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Bayesian Approaches","Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Convolutional Neural Networks","Convolutional Neural Networks","Decision Trees or Random Forests","Linear or Logistic Regression, Decision Trees or Random Forests, Convolutional Neural Networks","Linear or Logistic Regression, Bayesian Approaches","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Dense Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Dense Neural Networks, Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Dense Neural Networks, Convolutional Neural Networks","Linear or Logistic Regression, Convolutional Neural Networks","Decision Trees or Random Forests, Gradient Boosting Machines","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Gradient Boosting Machines","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Bayesian Approaches, Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Bayesian Approaches, Dense Neural Networks, Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Bayesian Approaches, Convolutional Neural Networks","Gradient Boosting Machines","Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches, Convolutional Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Recurrent Neural Networks","Dense Neural Networks, Convolutional Neural Networks","Linear or Logistic Regression, Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Dense Neural Networks, Convolutional Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Dense Neural Networks, Convolutional Neural Networks, Recurrent Neural Networks, Transformer Networks","Convolutional Neural Networks, Recurrent Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Bayesian Approaches, Convolutional Neural Networks, Recurrent Neural Networks","Other","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Bayesian Approaches, Dense Neural Networks","Linear or Logistic Regression, Decision Trees or Random Forests, Gradient Boosting Machines, Bayesian Approaches, Evolutionary Approaches, Dense Neural Networks, Convolutional Neural Networks, Generative Adversarial Networks, Recurrent Neural N ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# ## Additional

# %% [markdown]
# #### 18. What are the favorite media sources for data science topics?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['Who/what are your favorite media sources that report on data science topics?'])]['Who/what are your favorite media sources that report on data science topics?']
chart = pd.value_counts(s.str.split(expand=True).stack())
chart = chart.to_frame(name='data').sort_index()
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'Who/what are your favorite media sources that report on data science topics? Word Value Counts'},
    'xaxis': {'title': {'text': 'Who/what are your favorite media sources that report on data science topics?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\2828615906.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="51808f08-cf19-49a8-9e44-3d595ec7dced" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51808f08-cf19-49a8-9e44-3d595ec7dced")) {                    Plotly.newPlot(                        "51808f08-cf19-49a8-9e44-3d595ec7dced",                        [{"name":"Frequency","x":["Kaggle,","YouTube,","Blogs","Blogs,","Journal","Twitter,","Course","Publications","Forums,","Reddit,","Slack","Communities","Podcasts,","Hacker","News,","YouTube","Other","Publications,","Kaggle","Podcasts","Forums","Communities,","Reddit","Twitter","News"],"y":[6305,3627,3498,3139,3139,2468,2467,2453,2305,2108,1676,1607,1283,1209,1178,759,754,686,554,194,162,69,57,49,31],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{" ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.

# %% [markdown]
# #### 19. On which platforms have respondents completed data science courses?

# %%
# DISCLAIMER: 'df' refers to the data you passed in when calling 'dtale.show'

import numpy as np
import pandas as pd
import plotly.graph_objs as go

# If you're having trouble viewing your chart in your notebook try passing your 'chart' into this snippet:
#
from plotly.offline import iplot, init_notebook_mode
#
init_notebook_mode(connected=True)
for chart in charts:
    chart.pop('id', None) # for some reason iplot does not like 'id'

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

s = df[~pd.isnull(df['On which platforms have you begun or completed data science courses?'])]['On which platforms have you begun or completed data science courses?']
chart = pd.value_counts(s.str.split(expand=True).stack())
chart = chart.to_frame(name='data').sort_index()
chart['percent'] = (chart['data'] / chart['data'].sum()) * 100
chart.index.name = 'labels'
chart = chart.reset_index().sort_values(['data', 'labels'], ascending=[False, True])
chart = chart[:100]
charts = [go.Bar(x=chart['labels'].values, y=chart['data'].values, name='Frequency')]
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h'},
    'title': {'text': 'On which platforms have you begun or completed data science courses? Word Value Counts'},
    'xaxis': {'title': {'text': 'On which platforms have you begun or completed data science courses?'}},
    'yaxis': {'title': {'text': 'Frequency'}}
}))


iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\Muqri Qawiem\AppData\Local\Temp\ipykernel_9248\3291588829.py:23: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
# <div>                            <div id="7729c405-c087-4ae7-b178-1ab038e454c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7729c405-c087-4ae7-b178-1ab038e454c8")) {                    Plotly.newPlot(                        "7729c405-c087-4ae7-b178-1ab038e454c8",                        [{"name":"Frequency","x":["Coursera,","Courses","Kaggle","University","Courses,","DataCamp,","Udacity,","Udemy","edX,","Udemy,","Other","Coursera","LinkedIn","Fast.ai,","Learning","DataCamp","Fast.ai","DataQuest,","edX","Learning,","Udacity","DataQuest"],"y":[4923,3682,3279,2798,2395,2192,1968,1887,1870,1255,1092,971,851,644,526,496,463,397,328,325,103,80],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks" ...
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# c:\Python313\Lib\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# 2024-11-11 13:28:36,684 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1377, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 1343, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 1047, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#                     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 355, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 382, in concat
#     op = _Concatenator(
#         objs,
#     ...<8 lines>...
#         sort=sort,
#     )
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 445, in __init__
#     objs, keys = self._clean_keys_and_objs(objs, keys)
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 507, in _clean_keys_and_objs
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2024-11-11 13:34:42,161 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1377, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 1343, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 1047, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#                     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dtale\charts\utils.py", line 355, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 382, in concat
#     op = _Concatenator(
#         objs,
#     ...<8 lines>...
#         sort=sort,
#     )
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 445, in __init__
#     objs, keys = self._clean_keys_and_objs(objs, keys)
#                  ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\reshape\concat.py", line 507, in _clean_keys_and_objs
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2024-11-11 13:35:14,673 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1369, in group_values
#     group_types = get_group_types(inputs, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 686, in get_group_types
#     return _flags("group")
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 667, in _flags
#     col, freq = fgc.split(CHART_JOINER_CHAR)
#     ^^^^^^^^^
# ValueError: not enough values to unpack (expected 2, got 1)
# 2024-11-11 13:35:15,474 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1308, in main_input_class
#     return main_inputs_and_group_val_display(
#         dict_merge(
#     ...<8 lines>...
#         )
#     )
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 1387, in main_inputs_and_group_val_display
#     group_types = get_group_types(inputs)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 686, in get_group_types
#     return _flags("group")
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 667, in _flags
#     col, freq = fgc.split(CHART_JOINER_CHAR)
#     ^^^^^^^^^
# ValueError: not enough values to unpack (expected 2, got 1)
# 2024-11-11 13:35:18,273 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\views.py", line 1369, in group_values
#     group_types = get_group_types(inputs, group_cols)
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 686, in get_group_types
#     return _flags("group")
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\layout\layout.py", line 667, in _flags
#     col, freq = fgc.split(CHART_JOINER_CHAR)
#     ^^^^^^^^^
# ValueError: not enough values to unpack (expected 2, got 1)
# 2024-11-11 13:35:30,390 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\parsing.py", line 192, in tokenize_string
#     yield tokenize_backtick_quoted_string(
#           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         token_generator, source, string_start=start[1] + 1
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\parsing.py", line 162, in tokenize_backtick_quoted_string
#     for _, tokval, start, _, _ in token_generator:
#                                   ^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\tokenize.py", line 580, in _generate_tokens_from_c_tokenizer
#     raise TokenError(msg, (e.lineno, e.offset)) from None
# tokenize.TokenError: ('unexpected EOF in multi-line statement', (1, 0))
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\drilldown_modal.py", line 316, in load_drilldown_content
#     hist_chart = build_histogram(
#         data_id, y_col, query, point_filter
#     )
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\drilldown_modal.py", line 57, in build_histogram
#     data = run_query(data, query)
#   File "c:\Python313\Lib\site-packages\dtale\query.py", line 158, in run_query
#     df = df.query(
#         query if is_pandas25 else query.replace("`", ""),
#         local_dict=context_vars or {},
#         engine=engine,
#     )
#   File "c:\Python313\Lib\site-packages\pandas\core\frame.py", line 4823, in query
#     res = self.eval(expr, **kwargs)
#   File "c:\Python313\Lib\site-packages\pandas\core\frame.py", line 4949, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\eval.py", line 336, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 805, in __init__
#     self.terms = self.parse()
#                  ~~~~~~~~~~^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 824, in parse
#     return self._visitor.visit(self.expr)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 401, in visit
#     clean = self.preparser(node)
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 165, in _preparse
#     return tokenize.untokenize(f(x) for x in tokenize_string(source))
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\tokenize.py", line 333, in untokenize
#     out = ut.untokenize(iterable)
#   File "c:\Python313\Lib\tokenize.py", line 216, in untokenize
#     self.compat(t, it)
#     ~~~~~~~~~~~^^^^^^^
#   File "c:\Python313\Lib\tokenize.py", line 265, in compat
#     for tok in _itertools.chain([token], iterable):
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 165, in <genexpr>
#     return tokenize.untokenize(f(x) for x in tokenize_string(source))
#                                              ~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\parsing.py", line 196, in tokenize_string
#     raise SyntaxError(f"Failed to parse backticks in '{source}'.") from err
# SyntaxError: Failed to parse backticks in '(`What is your age (# years)?` == '25-29')'.
# 2024-11-11 13:35:35,746 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\parsing.py", line 192, in tokenize_string
#     yield tokenize_backtick_quoted_string(
#           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         token_generator, source, string_start=start[1] + 1
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\parsing.py", line 162, in tokenize_backtick_quoted_string
#     for _, tokval, start, _, _ in token_generator:
#                                   ^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\tokenize.py", line 580, in _generate_tokens_from_c_tokenizer
#     raise TokenError(msg, (e.lineno, e.offset)) from None
# tokenize.TokenError: ('unexpected EOF in multi-line statement', (1, 0))
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Python313\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\dash\dash.py", line 1376, in dispatch
#     ctx.run(
#     ~~~~~~~^
#         functools.partial(
#         ^^^^^^^^^^^^^^^^^^
#     ...<7 lines>...
#         )
#         ^
#     )
#     ^
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 507, in add_context
#     raise err
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 496, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "c:\Python313\Lib\site-packages\dash\_callback.py", line 43, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\drilldown_modal.py", line 316, in load_drilldown_content
#     hist_chart = build_histogram(
#         data_id, y_col, query, point_filter
#     )
#   File "c:\Python313\Lib\site-packages\dtale\dash_application\drilldown_modal.py", line 57, in build_histogram
#     data = run_query(data, query)
#   File "c:\Python313\Lib\site-packages\dtale\query.py", line 158, in run_query
#     df = df.query(
#         query if is_pandas25 else query.replace("`", ""),
#         local_dict=context_vars or {},
#         engine=engine,
#     )
#   File "c:\Python313\Lib\site-packages\pandas\core\frame.py", line 4823, in query
#     res = self.eval(expr, **kwargs)
#   File "c:\Python313\Lib\site-packages\pandas\core\frame.py", line 4949, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\eval.py", line 336, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 805, in __init__
#     self.terms = self.parse()
#                  ~~~~~~~~~~^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 824, in parse
#     return self._visitor.visit(self.expr)
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 401, in visit
#     clean = self.preparser(node)
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 165, in _preparse
#     return tokenize.untokenize(f(x) for x in tokenize_string(source))
#            ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\tokenize.py", line 333, in untokenize
#     out = ut.untokenize(iterable)
#   File "c:\Python313\Lib\tokenize.py", line 216, in untokenize
#     self.compat(t, it)
#     ~~~~~~~~~~~^^^^^^^
#   File "c:\Python313\Lib\tokenize.py", line 265, in compat
#     for tok in _itertools.chain([token], iterable):
#                ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\expr.py", line 165, in <genexpr>
#     return tokenize.untokenize(f(x) for x in tokenize_string(source))
#                                              ~~~~~~~~~~~~~~~^^^^^^^^
#   File "c:\Python313\Lib\site-packages\pandas\core\computation\parsing.py", line 196, in tokenize_string
#     raise SyntaxError(f"Failed to parse backticks in '{source}'.") from err
# SyntaxError: Failed to parse backticks in '(`What is your age (# years)?` == '25-29')'.

# %% [markdown]
# # Advanced EDA Questions

# %% [markdown]
# ## Demographic Analysis

# %% [markdown]
# #### Age Distribution by Gender: How does the age distribution vary between different genders?

# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

# Enable Plotly in offline mode
init_notebook_mode(connected=True)


# If the DataFrame has DateTimeIndex or MultiIndex, convert it
if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
    df = df.to_frame(index=False)

# Remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # Ensure column names are strings

# Filter data to include only 'Male' and 'Female' genders
chart_data = df[df['What is your gender?'].isin(['Female', 'Male'])]


chart_data = chart_data.rename(columns={'What is your age (# years)?': 'age'})

# Group by age and gender and count the occurrences
chart_data_count = chart_data.groupby(['What is your gender?', 'age']).size().reset_index(name='count')


female_data = chart_data_count[chart_data_count['What is your gender?'] == 'Female']
male_data = chart_data_count[chart_data_count['What is your gender?'] == 'Male']


charts = [
    go.Bar(x=female_data['age'], y=female_data['count'], name='Female'),
    go.Bar(x=male_data['age'], y=male_data['count'], name='Male')
]

# Create the figure
figure = go.Figure(data=charts, layout=go.Layout({
    'barmode': 'group',
    'legend': {'orientation': 'h', 'y': -0.3},
    'title': {'text': 'Age Distribution by Gender'},
    'xaxis': {'title': {'text': 'Age'}},
    'yaxis': {'title': {'text': 'Count'}, 'type': 'linear'}
}))

iplot(figure)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="c09a9bc2-0aa8-4bd6-922a-912e6252e3e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c09a9bc2-0aa8-4bd6-922a-912e6252e3e4")) {                    Plotly.newPlot(                        "c09a9bc2-0aa8-4bd6-922a-912e6252e3e4",                        [{"name":"Female","x":["18-21","22-24","25-29","30-34","35-39","40-44","45-49","50-54","55-59","60-69","70+"],"y":[45,216,411,306,178,128,73,48,24,12,4],"type":"bar"},{"name":"Male","x":["18-21","22-24","25-29","30-34","35-39","40-44","45-49","50-54","55-59","60-69","70+"],"y":[275,1103,2151,1785,1261,857,577,426,244,201,48],"type":"bar"}],                        {"barmode":"group","legend":{"orientation":"h","y":-0.3},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorb ...
